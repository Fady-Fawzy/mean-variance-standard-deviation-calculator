# %% [markdown]
# <a href="https://colab.research.google.com/github/Fady-Fawzy/mean-variance-standard-deviation-calculator/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > we will unzip the data and take a
# deep look on it

# %%
data_dir = os.path.join(path, "dogs-vs-cats-classification")

print(os.listdir(data_dir))
# Out:
# ['test', 'train', 'validation', 'dataset_info.csv']

# %%
import zipfile

ZipPath = "/content/cats_vs_dogs.zip"
with zipfile.ZipFile(ZipPath,"r" ) as zip:
  zip.extractall("/content/cats_vs_dogs")

# %%
TraningDir = os.path.join(data_dir, "train")
ValidationDir = os.path.join(data_dir, "validation")
TestDir = os.path.join(data_dir, "test")

# %% [markdown]
# > Start the show

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
TrainData = ImageDataGenerator (rescale = 1.0/250.)
ValidationData = ImageDataGenerator (rescale = 1.0/250.)

# %%
TrainGenerator = TrainData.flow_from_directory(
    TraningDir,
    target_size = (150,150),
    batch_size = 250,
    class_mode = "binary"
)
# Out:
# Found 19943 images belonging to 2 classes.

# %%
ValidationGenerator = ValidationData.flow_from_directory(
    ValidationDir,
    target_size = (150,150),
    batch_size = 250,
    class_mode = "binary"
)
# Out:
# Found 2492 images belonging to 2 classes.

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(
        16,
        (3,3),
        activation="relu",
        input_shape = (150,150,3)
    ),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(
        32,
        (3,3),
        activation="relu",
        input_shape = (150,150,3)
    ),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(
        64,
        (3,3),
        activation="relu",
        input_shape = (150,150,3)
    ),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(
        512,
        activation = "relu"
    ),
    tf.keras.layers.Dense(1,
        activation = "sigmoid"
    )


] )
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.optimizers import RMSprop

# %%
model.compile(
    optimizer= RMSprop(learning_rate = 0.001),
    loss = "binary_crossentropy",
    metrics = ["accuracy"]
)

# %%
traning = model.fit(
    TrainGenerator,
    epochs = 20,
    steps_per_epoch = 80,
    validation_data=ValidationGenerator,
    validation_steps=10

)
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 64s 684ms/step - accuracy: 0.5540 - loss: 0.7239 - val_accuracy: 0.6368 - val_loss: 0.6504
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 44s 556ms/step - accuracy: 0.6565 - loss: 0.6247 - val_accuracy: 0.6517 - val_loss: 0.6343
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 45s 565ms/step - accuracy: 0.6987 - loss: 0.5800 - val_accuracy: 0.7155 - val_loss: 0.5434
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 81s 550ms/step - accuracy: 0.7199 - loss: 0.5477 - val_accuracy: 0.7059 - val_loss: 0.5495
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 45s 567ms/step - accuracy: 0.7464 - loss: 0.5116 - val_accuracy: 0.7424 - val_loss: 0.5116
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 44s 556ms/step - accuracy: 0.7672 - loss: 0.4803 - val_accuracy: 0.7877 - val_loss: 0.4393
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 45s 558ms/step - accuracy: 0.7794 - loss: 0.4608 - val_accuracy: 0.7881 - val_loss: 0.4586
# Epoch 8/20
# ...

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9dab05a0-7296-46a4-adc2-72de43712ccc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9dab05a0-7296-46a4-adc2-72de43712ccc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = image.load_img(
    "Screenshot 2026-09-03 170050.png",
    target_size=(150, 150)
)

# %%
x = image.img_to_array(img)

# %%
x = np.expand_dims(x, axis=0)

# %%
images = np.vstack([x])

# %%
classes = model.predict(images, batch_size=10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
print(classes)
# Out:
# [[1.]]

# %%
print(TrainGenerator.class_indices)
# Out:
# {'cats': 0, 'dogs': 1}

# %%
if classes[0] > 0.5:
    print("It's a dog")
else:
    print("It's a cat")
# Out:
# It's a dog
